# %%
import numpy as np 
import pandas as pd

# %%
import os

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph.
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import average_precision_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.svm import SVC
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\agaho\OneDrive\Masaüstü\Agahoksuz\dataset.csv')
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.drop(['target'], axis = 1)
y = df.target.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
import keras
from keras.models import Sequential
from keras.layers import Dense
import warnings

# %%
chest_pain=pd.get_dummies(df['cp'],prefix='cp',drop_first=True)
df=pd.concat([df,chest_pain],axis=1)
df.drop(['cp'],axis=1,inplace=True)
sp=pd.get_dummies(df['slope'],prefix='slope')
th=pd.get_dummies(df['thal'],prefix='thal')
rest_ecg=pd.get_dummies(df['restecg'],prefix='restecg')
frames=[df,sp,th,rest_ecg]
df=pd.concat(frames,axis=1)
df.drop(['slope','thal','restecg'],axis=1,inplace=True)

# %%
X = df.drop(['target'], axis = 1)
y = df.target.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
import keras
from keras.models import Sequential
from keras.layers import Dense
import warnings

# %%
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense( 11, kernel_initializer = 'uniform', activation = 'relu', input_dim = 22))

# Adding the second hidden layer
classifier.add(Dense(11, bias_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(1, kernel_initializer = 'random_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 120)
# Out:
# Epoch 1/120
# 25/25 [==============================] - 2s 2ms/step - loss: 0.6914 - accuracy: 0.6612
# Epoch 2/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6827 - accuracy: 0.7893
# Epoch 3/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6601 - accuracy: 0.8223
# Epoch 4/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.8264
# Epoch 5/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.5549 - accuracy: 0.8223
# Epoch 6/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4949 - accuracy: 0.8223
# Epoch 7/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.8347
# Epoch 8/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8430
# Epoch 9/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3757 - accuracy: 0.8512
# Epoch 10/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3569 - accuracy: 0.8554
# Epoch 11/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8636
# Epoch 12/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8760
# Epoch 13/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8760
# Epoch 14/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3249 - accuracy: 0.8719
# Epoch 15/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.8678
# Epoch 16/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3154 - accuracy: 0.8678
# Epoch 17/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3095 - accuracy: 0.8636
# Epoch 18/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3064 - accuracy: 0.8636
# Epoch 19/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8678
# Epoch 20/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.8719
# Epoch 21/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2954 - accuracy: 0.8678
# Epoch 22/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2938 - accuracy: 0.8760
# Epoch 23/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.8843
# Epoch 24/120
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.8884
# Epoch 25/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2842 - accuracy: 0.8843
# Epoch 26/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2812 - accuracy: 0.9008
# Epoch 27/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2765 - accuracy: 0.8967
# Epoch 28/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2743 - accuracy: 0.9050
# Epoch 29/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2710 - accuracy: 0.9050
# Epoch 30/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2675 - accuracy: 0.9050
# Epoch 31/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2670 - accuracy: 0.9050
# Epoch 32/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2634 - accuracy: 0.9050
# Epoch 33/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2614 - accuracy: 0.9050
# Epoch 34/120
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2590 - accuracy: 0.9091
# Epoch 35/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2564 - accuracy: 0.9091
# Epoch 36/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2537 - accuracy: 0.9091
# Epoch 37/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2533 - accuracy: 0.9091
# Epoch 38/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2531 - accuracy: 0.9091
# Epoch 39/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2502 - accuracy: 0.9091
# Epoch 40/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2463 - accuracy: 0.9091
# Epoch 41/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2453 - accuracy: 0.9091
# Epoch 42/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2438 - accuracy: 0.9091
# Epoch 43/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2430 - accuracy: 0.9132
# Epoch 44/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2412 - accuracy: 0.9132
# Epoch 45/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2383 - accuracy: 0.9132
# Epoch 46/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2373 - accuracy: 0.9132
# Epoch 47/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2355 - accuracy: 0.9091
# Epoch 48/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2340 - accuracy: 0.9132
# Epoch 49/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2332 - accuracy: 0.9215
# Epoch 50/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2303 - accuracy: 0.9132
# Epoch 51/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2294 - accuracy: 0.9132
# Epoch 52/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.9215
# Epoch 53/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2261 - accuracy: 0.9215
# Epoch 54/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2245 - accuracy: 0.9174
# Epoch 55/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2217 - accuracy: 0.9256
# Epoch 56/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2207 - accuracy: 0.9215
# Epoch 57/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2189 - accuracy: 0.9215
# Epoch 58/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2167 - accuracy: 0.9298
# Epoch 59/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2158 - accuracy: 0.9298
# Epoch 60/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9298
# Epoch 61/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2120 - accuracy: 0.9298
# Epoch 62/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2117 - accuracy: 0.9298
# Epoch 63/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2095 - accuracy: 0.9339
# Epoch 64/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2076 - accuracy: 0.9339
# Epoch 65/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2059 - accuracy: 0.9298
# Epoch 66/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2042 - accuracy: 0.9339
# Epoch 67/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2036 - accuracy: 0.9339
# Epoch 68/120
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2019 - accuracy: 0.9298
# Epoch 69/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1993 - accuracy: 0.9380
# Epoch 70/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1981 - accuracy: 0.9380
# Epoch 71/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1964 - accuracy: 0.9380
# Epoch 72/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1957 - accuracy: 0.9380
# Epoch 73/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9380
# Epoch 74/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1926 - accuracy: 0.9380
# Epoch 75/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1917 - accuracy: 0.9339
# Epoch 76/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1887 - accuracy: 0.9380
# Epoch 77/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1870 - accuracy: 0.9380
# Epoch 78/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1863 - accuracy: 0.9339
# Epoch 79/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1848 - accuracy: 0.9380
# Epoch 80/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1826 - accuracy: 0.9380
# Epoch 81/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1810 - accuracy: 0.9380
# Epoch 82/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1805 - accuracy: 0.9380
# Epoch 83/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1790 - accuracy: 0.9421
# Epoch 84/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1756 - accuracy: 0.9421
# Epoch 85/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1754 - accuracy: 0.9421
# Epoch 86/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 0.9421
# Epoch 87/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1715 - accuracy: 0.9421
# Epoch 88/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1707 - accuracy: 0.9421
# Epoch 89/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1681 - accuracy: 0.9421
# Epoch 90/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9421
# Epoch 91/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1655 - accuracy: 0.9421
# Epoch 92/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1637 - accuracy: 0.9421
# Epoch 93/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9463
# Epoch 94/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1615 - accuracy: 0.9463
# Epoch 95/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1598 - accuracy: 0.9463
# Epoch 96/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1583 - accuracy: 0.9463
# Epoch 97/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1567 - accuracy: 0.9463
# Epoch 98/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1548 - accuracy: 0.9463
# Epoch 99/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1545 - accuracy: 0.9463
# Epoch 100/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.9463
# Epoch 101/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1503 - accuracy: 0.9463
# Epoch 102/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1492 - accuracy: 0.9504
# Epoch 103/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9545
# Epoch 104/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1465 - accuracy: 0.9545
# Epoch 105/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1437 - accuracy: 0.9545
# Epoch 106/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1428 - accuracy: 0.9545
# Epoch 107/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1404 - accuracy: 0.9504
# Epoch 108/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1382 - accuracy: 0.9545
# Epoch 109/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1382 - accuracy: 0.9545
# Epoch 110/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1347 - accuracy: 0.9504
# Epoch 111/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1343 - accuracy: 0.9587
# Epoch 112/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1301 - accuracy: 0.9628
# Epoch 113/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1328 - accuracy: 0.9628
# Epoch 114/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1294 - accuracy: 0.9628
# Epoch 115/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1269 - accuracy: 0.9669
# Epoch 116/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.1251 - accuracy: 0.9669
# Epoch 117/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1233 - accuracy: 0.9711
# Epoch 118/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1221 - accuracy: 0.9752
# Epoch 119/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1198 - accuracy: 0.9669
# Epoch 120/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1186 - accuracy: 0.9669

# %%
y_pred = classifier.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred.round())
sns.heatmap(cm,annot=True,cmap="Blues",fmt="d",cbar=False)
#accuracy score
from sklearn.metrics import accuracy_score
ac=accuracy_score(y_test, y_pred.round())
print('accuracy of the model: ',ac)
# Out:
# accuracy of the model:  0.9016393442622951
